# %%
from polymer_utils import *

# %% [markdown]
# # First, generate templates to assign chemical information

# %%
file = "polymer_examples/rdkit_simple_polymers/naturalrubber.pdb"
p = ParsePolymer(file)
p.monomer_ids = p.generate_ids(6, [20], [])
p.monomer_context_ids = p.generate_ids(6, [20], [])

# %%
p.visualize(width=800, height=1000, highlight_ids = p.monomer_ids)

# %%
new_samrts, smarts_block = p.generate_smarts_entry()
print(smarts_block)
# Out:
# "[C:1](-[H:2])(-[H:3])-[C:4](-[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]": [
# 	"C1",
# 	"H1",
# 	"H2",
# 	"C2",
# 	"C3",
# 	"H3",
# 	"C4",
# 	"H4",
# 	"H5",
# 	"C5",
# 	"H6",
# 	"H7",
# 	"H8"
# ]

# %% [markdown]
# # After test load the molecule to check for missing chemical info

# %%
p.test_polymer_load()
# Out:
# NATURALRUBBER
# [C:1](-[H:2])(-[H:3])(-[H:4])-[C:5](=[C:6](-[H:7])-[C:8](-[H:9])-[H:10])-[C:11](-[H:12])(-[H:13])-[H:14]
# NATURALRUBBER
# [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])(-[H:9])-[H:10])-[C:11](-[H:12])(-[H:13])-[H:14]
# NATURALRUBBER
# [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]
# DEFAULT_MONOMER_BOND
# [C:1]([H:3])([H:4])[C:2]([H:5])([H:6])
# N. of assigned nodes: 106 -- N. of atoms: 106
# N. of assigned edges: 112 -- N. of bonds: 105
# 0 {'atomic_number': 6, 'formal_charge': 0, 'atom_name': 'C', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])(-[H:9])-[H:10])-[C:11](-[H:12])(-[H:13])-[H:14]', 'connors_residue_number': 2, 'connors_atom_name': 'C1'}
# Formal charge: 0
# 1 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'H', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])(-[H:9])-[H:10])-[C:11](-[H:12])(-[H:13])-[H:14]', 'connors_residue_number': 2, 'connors_atom_name': 'H1'}
# Formal charge: 0
# 2 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'H1', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])(-[H:9])-[H:10])-[C:11](-[H:12])(-[H:13])-[H:14]', 'connors_residue_number': 2, 'connors_atom_name': 'H2'}
# Formal charge: 0
# 3 {'atomic_number': 6, 'formal_charge': 0, 'atom_name': 'C1', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])(-[H:9])-[H:10])-[C:11](-[H:12])(-[H:13])-[H:14]', 'connors_residue_number': 2, 'connors_atom_name': 'C2'}
# Formal charge: 0
# 4 {'atomic_number': 6, 'formal_charge': 0, 'atom_name': 'C2', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])(-[H:9])-[H:10])-[C:11](-[H:12])(-[H:13])-[H:14]', 'connors_residue_number': 2, 'connors_atom_name': 'C3'}
# Formal charge: 0
# 5 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'H2', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])(-[H:9])-[H:10])-[C:11](-[H:12])(-[H:13])-[H:14]', 'connors_residue_number': 2, 'connors_atom_name': 'H3'}
# Formal charge: 0
# 6 {'atomic_number': 6, 'formal_charge': 0, 'atom_name': 'C3', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])(-[H:9])-[H:10])-[C:11](-[H:12])(-[H:13])-[H:14]', 'connors_residue_number': 2, 'connors_atom_name': 'C4'}
# Formal charge: 0
# 7 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'H3', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])(-[H:9])-[H:10])-[C:11](-[H:12])(-[H:13])-[H:14]', 'connors_residue_number': 2, 'connors_atom_name': 'H4'}
# Formal charge: 0
# 8 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'H4', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])(-[H:9])-[H:10])-[C:11](-[H:12])(-[H:13])-[H:14]', 'connors_residue_number': 2, 'connors_atom_name': 'H5'}
# Formal charge: 0
# 9 {'atomic_number': 6, 'formal_charge': 0, 'atom_name': 'C4', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])(-[H:9])-[H:10])-[C:11](-[H:12])(-[H:13])-[H:14]', 'connors_residue_number': 2, 'connors_atom_name': 'C5'}
# Formal charge: 0
# 10 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'H5', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])(-[H:9])-[H:10])-[C:11](-[H:12])(-[H:13])-[H:14]', 'connors_residue_number': 2, 'connors_atom_name': 'H7'}
# Formal charge: 0
# 11 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'H6', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])(-[H:9])-[H:10])-[C:11](-[H:12])(-[H:13])-[H:14]', 'connors_residue_number': 2, 'connors_atom_name': 'H8'}
# Formal charge: 0
# 12 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'H7', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])(-[H:9])-[H:10])-[C:11](-[H:12])(-[H:13])-[H:14]', 'connors_residue_number': 2, 'connors_atom_name': 'H9'}
# Formal charge: 0
# 13 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'H8', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])(-[H:9])-[H:10])-[C:11](-[H:12])(-[H:13])-[H:14]', 'connors_residue_number': 2, 'connors_atom_name': 'H6'}
# Formal charge: 0
# 14 {'atomic_number': 6, 'formal_charge': 0, 'atom_name': 'C5', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 3, 'connors_atom_name': 'C1'}
# Formal charge: 0
# 15 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'H9', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 3, 'connors_atom_name': 'H1'}
# Formal charge: 0
# 16 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'Ha', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 3, 'connors_atom_name': 'H2'}
# Formal charge: 0
# 17 {'atomic_number': 6, 'formal_charge': 0, 'atom_name': 'C6', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 3, 'connors_atom_name': 'C2'}
# Formal charge: 0
# 18 {'atomic_number': 6, 'formal_charge': 0, 'atom_name': 'C7', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 3, 'connors_atom_name': 'C3'}
# Formal charge: 0
# 19 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'Hb', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 3, 'connors_atom_name': 'H3'}
# Formal charge: 0
# 20 {'atomic_number': 6, 'formal_charge': 0, 'atom_name': 'C8', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 3, 'connors_atom_name': 'C4'}
# Formal charge: 0
# 21 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'Hc', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 3, 'connors_atom_name': 'H4'}
# Formal charge: 0
# 22 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'Hd', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 3, 'connors_atom_name': 'H5'}
# Formal charge: 0
# 23 {'atomic_number': 6, 'formal_charge': 0, 'atom_name': 'C9', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 3, 'connors_atom_name': 'C5'}
# Formal charge: 0
# 24 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'He', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 3, 'connors_atom_name': 'H6'}
# Formal charge: 0
# 25 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'Hf', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 3, 'connors_atom_name': 'H7'}
# Formal charge: 0
# 26 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'Hg', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 3, 'connors_atom_name': 'H8'}
# Formal charge: 0
# 27 {'atomic_number': 6, 'formal_charge': 0, 'atom_name': 'Ca', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 4, 'connors_atom_name': 'C1'}
# Formal charge: 0
# 28 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'Hh', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 4, 'connors_atom_name': 'H1'}
# Formal charge: 0
# 29 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'Hi', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 4, 'connors_atom_name': 'H2'}
# Formal charge: 0
# 30 {'atomic_number': 6, 'formal_charge': 0, 'atom_name': 'Cb', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 4, 'connors_atom_name': 'C2'}
# Formal charge: 0
# 31 {'atomic_number': 6, 'formal_charge': 0, 'atom_name': 'Cc', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 4, 'connors_atom_name': 'C3'}
# Formal charge: 0
# 32 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'Hj', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 4, 'connors_atom_name': 'H3'}
# Formal charge: 0
# 33 {'atomic_number': 6, 'formal_charge': 0, 'atom_name': 'Cd', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 4, 'connors_atom_name': 'C4'}
# Formal charge: 0
# 34 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'Hk', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 4, 'connors_atom_name': 'H4'}
# Formal charge: 0
# 35 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'Hl', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 4, 'connors_atom_name': 'H5'}
# Formal charge: 0
# 36 {'atomic_number': 6, 'formal_charge': 0, 'atom_name': 'Ce', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 4, 'connors_atom_name': 'C5'}
# Formal charge: 0
# 37 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'Hm', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 4, 'connors_atom_name': 'H6'}
# Formal charge: 0
# 38 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'Hn', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 4, 'connors_atom_name': 'H7'}
# Formal charge: 0
# 39 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'Ho', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 4, 'connors_atom_name': 'H8'}
# Formal charge: 0
# 40 {'atomic_number': 6, 'formal_charge': 0, 'atom_name': 'Cf', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 5, 'connors_atom_name': 'C1'}
# Formal charge: 0
# 41 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'Hp', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 5, 'connors_atom_name': 'H1'}
# Formal charge: 0
# 42 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'Hq', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 5, 'connors_atom_name': 'H2'}
# Formal charge: 0
# 43 {'atomic_number': 6, 'formal_charge': 0, 'atom_name': 'Cg', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 5, 'connors_atom_name': 'C2'}
# Formal charge: 0
# 44 {'atomic_number': 6, 'formal_charge': 0, 'atom_name': 'Ch', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 5, 'connors_atom_name': 'C3'}
# Formal charge: 0
# 45 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'Hr', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 5, 'connors_atom_name': 'H3'}
# Formal charge: 0
# 46 {'atomic_number': 6, 'formal_charge': 0, 'atom_name': 'Ci', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 5, 'connors_atom_name': 'C4'}
# Formal charge: 0
# 47 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'Hs', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 5, 'connors_atom_name': 'H4'}
# Formal charge: 0
# 48 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'Ht', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 5, 'connors_atom_name': 'H5'}
# Formal charge: 0
# 49 {'atomic_number': 6, 'formal_charge': 0, 'atom_name': 'Cj', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 5, 'connors_atom_name': 'C5'}
# Formal charge: 0
# 50 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'Hu', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 5, 'connors_atom_name': 'H6'}
# Formal charge: 0
# 51 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'Hv', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 5, 'connors_atom_name': 'H7'}
# Formal charge: 0
# 52 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'Hw', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 5, 'connors_atom_name': 'H8'}
# Formal charge: 0
# 53 {'atomic_number': 6, 'formal_charge': 0, 'atom_name': 'Ck', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 6, 'connors_atom_name': 'C1'}
# Formal charge: 0
# 54 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'Hx', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 6, 'connors_atom_name': 'H1'}
# Formal charge: 0
# 55 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'Hz', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 6, 'connors_atom_name': 'H2'}
# Formal charge: 0
# 56 {'atomic_number': 6, 'formal_charge': 0, 'atom_name': 'Cl', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 6, 'connors_atom_name': 'C2'}
# Formal charge: 0
# 57 {'atomic_number': 6, 'formal_charge': 0, 'atom_name': 'Cm', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 6, 'connors_atom_name': 'C3'}
# Formal charge: 0
# 58 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'Hy', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 6, 'connors_atom_name': 'H3'}
# Formal charge: 0
# 59 {'atomic_number': 6, 'formal_charge': 0, 'atom_name': 'Cn', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 6, 'connors_atom_name': 'C4'}
# Formal charge: 0
# 60 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'HA', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 6, 'connors_atom_name': 'H4'}
# Formal charge: 0
# 61 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'HB', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 6, 'connors_atom_name': 'H5'}
# Formal charge: 0
# 62 {'atomic_number': 6, 'formal_charge': 0, 'atom_name': 'Co', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 6, 'connors_atom_name': 'C5'}
# Formal charge: 0
# 63 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'HC', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 6, 'connors_atom_name': 'H6'}
# Formal charge: 0
# 64 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'HD', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 6, 'connors_atom_name': 'H7'}
# Formal charge: 0
# 65 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'HE', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 6, 'connors_atom_name': 'H8'}
# Formal charge: 0
# 66 {'atomic_number': 6, 'formal_charge': 0, 'atom_name': 'Cp', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 7, 'connors_atom_name': 'C1'}
# Formal charge: 0
# 67 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'HF', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 7, 'connors_atom_name': 'H1'}
# Formal charge: 0
# 68 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'HG', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 7, 'connors_atom_name': 'H2'}
# Formal charge: 0
# 69 {'atomic_number': 6, 'formal_charge': 0, 'atom_name': 'Cq', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 7, 'connors_atom_name': 'C2'}
# Formal charge: 0
# 70 {'atomic_number': 6, 'formal_charge': 0, 'atom_name': 'Cr', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 7, 'connors_atom_name': 'C3'}
# Formal charge: 0
# 71 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'HH', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 7, 'connors_atom_name': 'H3'}
# Formal charge: 0
# 72 {'atomic_number': 6, 'formal_charge': 0, 'atom_name': 'Cs', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 7, 'connors_atom_name': 'C4'}
# Formal charge: 0
# 73 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'HI', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 7, 'connors_atom_name': 'H4'}
# Formal charge: 0
# 74 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'HJ', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 7, 'connors_atom_name': 'H5'}
# Formal charge: 0
# 75 {'atomic_number': 6, 'formal_charge': 0, 'atom_name': 'Ct', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 7, 'connors_atom_name': 'C5'}
# Formal charge: 0
# 76 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'HK', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 7, 'connors_atom_name': 'H6'}
# Formal charge: 0
# 77 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'HL', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 7, 'connors_atom_name': 'H7'}
# Formal charge: 0
# 78 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'HM', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 7, 'connors_atom_name': 'H8'}
# Formal charge: 0
# 79 {'atomic_number': 6, 'formal_charge': 0, 'atom_name': 'Cu', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 8, 'connors_atom_name': 'C1'}
# Formal charge: 0
# 80 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'HN', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 8, 'connors_atom_name': 'H1'}
# Formal charge: 0
# 81 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'HO', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 8, 'connors_atom_name': 'H2'}
# Formal charge: 0
# 82 {'atomic_number': 6, 'formal_charge': 0, 'atom_name': 'Cv', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 8, 'connors_atom_name': 'C2'}
# Formal charge: 0
# 83 {'atomic_number': 6, 'formal_charge': 0, 'atom_name': 'Cw', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 8, 'connors_atom_name': 'C3'}
# Formal charge: 0
# 84 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'HP', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 8, 'connors_atom_name': 'H3'}
# Formal charge: 0
# 85 {'atomic_number': 6, 'formal_charge': 0, 'atom_name': 'Cx', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 8, 'connors_atom_name': 'C4'}
# Formal charge: 0
# 86 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'HQ', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 8, 'connors_atom_name': 'H4'}
# Formal charge: 0
# 87 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'HR', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 8, 'connors_atom_name': 'H5'}
# Formal charge: 0
# 88 {'atomic_number': 6, 'formal_charge': 0, 'atom_name': 'Cz', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 8, 'connors_atom_name': 'C5'}
# Formal charge: 0
# 89 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'HS', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 8, 'connors_atom_name': 'H6'}
# Formal charge: 0
# 90 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'HT', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 8, 'connors_atom_name': 'H7'}
# Formal charge: 0
# 91 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'HU', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 8, 'connors_atom_name': 'H8'}
# Formal charge: 0
# 92 {'atomic_number': 6, 'formal_charge': 0, 'atom_name': 'Cy', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])(-[H:4])-[C:5](=[C:6](-[H:7])-[C:8](-[H:9])-[H:10])-[C:11](-[H:12])(-[H:13])-[H:14]', 'connors_residue_number': 1, 'connors_atom_name': 'C1'}
# Formal charge: 0
# 93 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'HV', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])(-[H:4])-[C:5](=[C:6](-[H:7])-[C:8](-[H:9])-[H:10])-[C:11](-[H:12])(-[H:13])-[H:14]', 'connors_residue_number': 1, 'connors_atom_name': 'H1'}
# Formal charge: 0
# 94 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'HW', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])(-[H:4])-[C:5](=[C:6](-[H:7])-[C:8](-[H:9])-[H:10])-[C:11](-[H:12])(-[H:13])-[H:14]', 'connors_residue_number': 1, 'connors_atom_name': 'H2'}
# Formal charge: 0
# 95 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'HX', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])(-[H:4])-[C:5](=[C:6](-[H:7])-[C:8](-[H:9])-[H:10])-[C:11](-[H:12])(-[H:13])-[H:14]', 'connors_residue_number': 1, 'connors_atom_name': 'H3'}
# Formal charge: 0
# 96 {'atomic_number': 6, 'formal_charge': 0, 'atom_name': 'CA', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])(-[H:4])-[C:5](=[C:6](-[H:7])-[C:8](-[H:9])-[H:10])-[C:11](-[H:12])(-[H:13])-[H:14]', 'connors_residue_number': 1, 'connors_atom_name': 'C2'}
# Formal charge: 0
# 97 {'atomic_number': 6, 'formal_charge': 0, 'atom_name': 'CB', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])(-[H:4])-[C:5](=[C:6](-[H:7])-[C:8](-[H:9])-[H:10])-[C:11](-[H:12])(-[H:13])-[H:14]', 'connors_residue_number': 1, 'connors_atom_name': 'C3'}
# Formal charge: 0
# 98 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'HY', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])(-[H:4])-[C:5](=[C:6](-[H:7])-[C:8](-[H:9])-[H:10])-[C:11](-[H:12])(-[H:13])-[H:14]', 'connors_residue_number': 1, 'connors_atom_name': 'H4'}
# Formal charge: 0
# 99 {'atomic_number': 6, 'formal_charge': 0, 'atom_name': 'CC', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])(-[H:4])-[C:5](=[C:6](-[H:7])-[C:8](-[H:9])-[H:10])-[C:11](-[H:12])(-[H:13])-[H:14]', 'connors_residue_number': 1, 'connors_atom_name': 'C4'}
# Formal charge: 0
# 100 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'HZ', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])(-[H:4])-[C:5](=[C:6](-[H:7])-[C:8](-[H:9])-[H:10])-[C:11](-[H:12])(-[H:13])-[H:14]', 'connors_residue_number': 1, 'connors_atom_name': 'H5'}
# Formal charge: 0
# 101 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'H!', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])(-[H:4])-[C:5](=[C:6](-[H:7])-[C:8](-[H:9])-[H:10])-[C:11](-[H:12])(-[H:13])-[H:14]', 'connors_residue_number': 1, 'connors_atom_name': 'H6'}
# Formal charge: 0
# 102 {'atomic_number': 6, 'formal_charge': 0, 'atom_name': 'CD', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])(-[H:4])-[C:5](=[C:6](-[H:7])-[C:8](-[H:9])-[H:10])-[C:11](-[H:12])(-[H:13])-[H:14]', 'connors_residue_number': 1, 'connors_atom_name': 'C5'}
# Formal charge: 0
# 103 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'H@', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])(-[H:4])-[C:5](=[C:6](-[H:7])-[C:8](-[H:9])-[H:10])-[C:11](-[H:12])(-[H:13])-[H:14]', 'connors_residue_number': 1, 'connors_atom_name': 'H7'}
# Formal charge: 0
# 104 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'H#', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])(-[H:4])-[C:5](=[C:6](-[H:7])-[C:8](-[H:9])-[H:10])-[C:11](-[H:12])(-[H:13])-[H:14]', 'connors_residue_number': 1, 'connors_atom_name': 'H8'}
# Formal charge: 0
# 105 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'H$', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])(-[H:4])-[C:5](=[C:6](-[H:7])-[C:8](-[H:9])-[H:10])-[C:11](-[H:12])(-[H:13])-[H:14]', 'connors_residue_number': 1, 'connors_atom_name': 'H9'}
# Formal charge: 0
# (0, 1) {'bond_order': 1}
# (0, 2) {'bond_order': 1}
# (0, 3) {'bond_order': 1}
# (0, 20) {'bond_order': 1}
# (3, 4) {'bond_order': 2}
# (3, 9) {'bond_order': 1}
# (4, 5) {'bond_order': 1}
# (4, 6) {'bond_order': 1}
# (6, 7) {'bond_order': 1}
# (6, 8) {'bond_order': 1}
# (6, 13) {'bond_order': 1}
# (9, 10) {'bond_order': 1}
# (9, 11) {'bond_order': 1}
# (9, 12) {'bond_order': 1}
# (14, 15) {'bond_order': 1}
# (14, 16) {'bond_order': 1}
# (14, 17) {'bond_order': 1}
# (14, 33) {'bond_order': 1}
# (17, 18) {'bond_order': 2}
# (17, 23) {'bond_order': 1}
# (18, 19) {'bond_order': 1}
# (18, 20) {'bond_order': 1}
# (20, 21) {'bond_order': 1}
# (20, 22) {'bond_order': 1}
# (23, 24) {'bond_order': 1}
# (23, 25) {'bond_order': 1}
# (23, 26) {'bond_order': 1}
# (27, 28) {'bond_order': 1}
# (27, 29) {'bond_order': 1}
# (27, 30) {'bond_order': 1}
# (27, 46) {'bond_order': 1}
# (30, 31) {'bond_order': 2}
# (30, 36) {'bond_order': 1}
# (31, 32) {'bond_order': 1}
# (31, 33) {'bond_order': 1}
# (33, 34) {'bond_order': 1}
# (33, 35) {'bond_order': 1}
# (36, 37) {'bond_order': 1}
# (36, 38) {'bond_order': 1}
# (36, 39) {'bond_order': 1}
# (40, 41) {'bond_order': 1}
# (40, 42) {'bond_order': 1}
# (40, 43) {'bond_order': 1}
# (40, 59) {'bond_order': 1}
# (43, 44) {'bond_order': 2}
# (43, 49) {'bond_order': 1}
# (44, 45) {'bond_order': 1}
# (44, 46) {'bond_order': 1}
# (46, 47) {'bond_order': 1}
# (46, 48) {'bond_order': 1}
# (49, 50) {'bond_order': 1}
# (49, 51) {'bond_order': 1}
# (49, 52) {'bond_order': 1}
# (53, 54) {'bond_order': 1}
# (53, 55) {'bond_order': 1}
# (53, 56) {'bond_order': 1}
# (53, 72) {'bond_order': 1}
# (56, 57) {'bond_order': 2}
# (56, 62) {'bond_order': 1}
# (57, 58) {'bond_order': 1}
# (57, 59) {'bond_order': 1}
# (59, 60) {'bond_order': 1}
# (59, 61) {'bond_order': 1}
# (62, 63) {'bond_order': 1}
# (62, 64) {'bond_order': 1}
# (62, 65) {'bond_order': 1}
# (66, 67) {'bond_order': 1}
# (66, 68) {'bond_order': 1}
# (66, 69) {'bond_order': 1}
# (66, 85) {'bond_order': 1}
# (69, 70) {'bond_order': 2}
# (69, 75) {'bond_order': 1}
# (70, 71) {'bond_order': 1}
# (70, 72) {'bond_order': 1}
# (72, 73) {'bond_order': 1}
# (72, 74) {'bond_order': 1}
# (75, 76) {'bond_order': 1}
# (75, 77) {'bond_order': 1}
# (75, 78) {'bond_order': 1}
# (79, 80) {'bond_order': 1}
# (79, 81) {'bond_order': 1}
# (79, 82) {'bond_order': 1}
# (79, 99) {'bond_order': 1}
# (82, 83) {'bond_order': 2}
# (82, 88) {'bond_order': 1}
# (83, 84) {'bond_order': 1}
# (83, 85) {'bond_order': 1}
# (85, 86) {'bond_order': 1}
# (85, 87) {'bond_order': 1}
# (88, 89) {'bond_order': 1}
# (88, 90) {'bond_order': 1}
# (88, 91) {'bond_order': 1}
# (92, 93) {'bond_order': 1}
# (92, 94) {'bond_order': 1}
# (92, 95) {'bond_order': 1}
# (92, 96) {'bond_order': 1}
# (96, 97) {'bond_order': 2}
# (96, 102) {'bond_order': 1}
# (97, 98) {'bond_order': 1}
# (97, 99) {'bond_order': 1}
# (99, 100) {'bond_order': 1}
# (99, 101) {'bond_order': 1}
# (102, 103) {'bond_order': 1}
# (102, 104) {'bond_order': 1}
# (102, 105) {'bond_order': 1}
# Number of atoms before sanitization: 106
# number of atoms assigned: 106
# number of bonds assigned: 105
# number of atoms not assigned: 0
# number of bonds not assigned: 0

# %% [markdown]
# # Next Generate library charges using a monomer or a monomer + Context

# %%
entry = p.generate_library_charge_entry()
# Out:
# NATURALRUBBER
# [C:1](-[H:2])(-[H:3])(-[H:4])-[C:5](=[C:6](-[H:7])-[C:8](-[H:9])-[H:10])-[C:11](-[H:12])(-[H:13])-[H:14]
# NATURALRUBBER
# [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])(-[H:9])-[H:10])-[C:11](-[H:12])(-[H:13])-[H:14]
# NATURALRUBBER
# [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]
# Warning (not error because allow_undefined_stereo=True): Unable to make OFFMol from RDMol: RDMol has unspecified stereochemistry. Undefined chiral centers are:
#  - Atom C (index 0)
#  - Atom C (index 6)
#  - Atom C (index 9)
# Bonds with undefined stereochemistry are:
#  - Bond 7 (atoms 3-4 of element (C-C)
# DEFAULT_MONOMER_BOND
# [C:1]([H:3])([H:4])[C:2]([H:5])([H:6])
# N. of assigned nodes: 106 -- N. of atoms: 106
# N. of assigned edges: 112 -- N. of bonds: 105
# 0 {'atomic_number': 6, 'formal_charge': 0, 'atom_name': 'C', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])(-[H:9])-[H:10])-[C:11](-[H:12])(-[H:13])-[H:14]', 'connors_residue_number': 2, 'connors_atom_name': 'C1'}
# Formal charge: 0
# 1 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'H', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])(-[H:9])-[H:10])-[C:11](-[H:12])(-[H:13])-[H:14]', 'connors_residue_number': 2, 'connors_atom_name': 'H1'}
# Formal charge: 0
# 2 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'H1', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])(-[H:9])-[H:10])-[C:11](-[H:12])(-[H:13])-[H:14]', 'connors_residue_number': 2, 'connors_atom_name': 'H2'}
# Formal charge: 0
# 3 {'atomic_number': 6, 'formal_charge': 0, 'atom_name': 'C1', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])(-[H:9])-[H:10])-[C:11](-[H:12])(-[H:13])-[H:14]', 'connors_residue_number': 2, 'connors_atom_name': 'C2'}
# Formal charge: 0
# 4 {'atomic_number': 6, 'formal_charge': 0, 'atom_name': 'C2', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])(-[H:9])-[H:10])-[C:11](-[H:12])(-[H:13])-[H:14]', 'connors_residue_number': 2, 'connors_atom_name': 'C3'}
# Formal charge: 0
# 5 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'H2', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])(-[H:9])-[H:10])-[C:11](-[H:12])(-[H:13])-[H:14]', 'connors_residue_number': 2, 'connors_atom_name': 'H3'}
# Formal charge: 0
# 6 {'atomic_number': 6, 'formal_charge': 0, 'atom_name': 'C3', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])(-[H:9])-[H:10])-[C:11](-[H:12])(-[H:13])-[H:14]', 'connors_residue_number': 2, 'connors_atom_name': 'C4'}
# Formal charge: 0
# 7 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'H3', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])(-[H:9])-[H:10])-[C:11](-[H:12])(-[H:13])-[H:14]', 'connors_residue_number': 2, 'connors_atom_name': 'H4'}
# Formal charge: 0
# 8 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'H4', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])(-[H:9])-[H:10])-[C:11](-[H:12])(-[H:13])-[H:14]', 'connors_residue_number': 2, 'connors_atom_name': 'H5'}
# Formal charge: 0
# 9 {'atomic_number': 6, 'formal_charge': 0, 'atom_name': 'C4', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])(-[H:9])-[H:10])-[C:11](-[H:12])(-[H:13])-[H:14]', 'connors_residue_number': 2, 'connors_atom_name': 'C5'}
# Formal charge: 0
# 10 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'H5', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])(-[H:9])-[H:10])-[C:11](-[H:12])(-[H:13])-[H:14]', 'connors_residue_number': 2, 'connors_atom_name': 'H7'}
# Formal charge: 0
# 11 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'H6', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])(-[H:9])-[H:10])-[C:11](-[H:12])(-[H:13])-[H:14]', 'connors_residue_number': 2, 'connors_atom_name': 'H8'}
# Formal charge: 0
# 12 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'H7', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])(-[H:9])-[H:10])-[C:11](-[H:12])(-[H:13])-[H:14]', 'connors_residue_number': 2, 'connors_atom_name': 'H9'}
# Formal charge: 0
# 13 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'H8', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])(-[H:9])-[H:10])-[C:11](-[H:12])(-[H:13])-[H:14]', 'connors_residue_number': 2, 'connors_atom_name': 'H6'}
# Formal charge: 0
# 14 {'atomic_number': 6, 'formal_charge': 0, 'atom_name': 'C5', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 3, 'connors_atom_name': 'C1'}
# Formal charge: 0
# 15 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'H9', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 3, 'connors_atom_name': 'H1'}
# Formal charge: 0
# 16 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'Ha', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 3, 'connors_atom_name': 'H2'}
# Formal charge: 0
# 17 {'atomic_number': 6, 'formal_charge': 0, 'atom_name': 'C6', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 3, 'connors_atom_name': 'C2'}
# Formal charge: 0
# 18 {'atomic_number': 6, 'formal_charge': 0, 'atom_name': 'C7', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 3, 'connors_atom_name': 'C3'}
# Formal charge: 0
# 19 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'Hb', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 3, 'connors_atom_name': 'H3'}
# Formal charge: 0
# 20 {'atomic_number': 6, 'formal_charge': 0, 'atom_name': 'C8', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 3, 'connors_atom_name': 'C4'}
# Formal charge: 0
# 21 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'Hc', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 3, 'connors_atom_name': 'H4'}
# Formal charge: 0
# 22 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'Hd', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 3, 'connors_atom_name': 'H5'}
# Formal charge: 0
# 23 {'atomic_number': 6, 'formal_charge': 0, 'atom_name': 'C9', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 3, 'connors_atom_name': 'C5'}
# Formal charge: 0
# 24 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'He', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 3, 'connors_atom_name': 'H6'}
# Formal charge: 0
# 25 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'Hf', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 3, 'connors_atom_name': 'H7'}
# Formal charge: 0
# 26 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'Hg', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 3, 'connors_atom_name': 'H8'}
# Formal charge: 0
# 27 {'atomic_number': 6, 'formal_charge': 0, 'atom_name': 'Ca', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 4, 'connors_atom_name': 'C1'}
# Formal charge: 0
# 28 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'Hh', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 4, 'connors_atom_name': 'H1'}
# Formal charge: 0
# 29 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'Hi', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 4, 'connors_atom_name': 'H2'}
# Formal charge: 0
# 30 {'atomic_number': 6, 'formal_charge': 0, 'atom_name': 'Cb', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 4, 'connors_atom_name': 'C2'}
# Formal charge: 0
# 31 {'atomic_number': 6, 'formal_charge': 0, 'atom_name': 'Cc', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 4, 'connors_atom_name': 'C3'}
# Formal charge: 0
# 32 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'Hj', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 4, 'connors_atom_name': 'H3'}
# Formal charge: 0
# 33 {'atomic_number': 6, 'formal_charge': 0, 'atom_name': 'Cd', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 4, 'connors_atom_name': 'C4'}
# Formal charge: 0
# 34 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'Hk', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 4, 'connors_atom_name': 'H4'}
# Formal charge: 0
# 35 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'Hl', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 4, 'connors_atom_name': 'H5'}
# Formal charge: 0
# 36 {'atomic_number': 6, 'formal_charge': 0, 'atom_name': 'Ce', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 4, 'connors_atom_name': 'C5'}
# Formal charge: 0
# 37 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'Hm', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 4, 'connors_atom_name': 'H6'}
# Formal charge: 0
# 38 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'Hn', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 4, 'connors_atom_name': 'H7'}
# Formal charge: 0
# 39 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'Ho', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 4, 'connors_atom_name': 'H8'}
# Formal charge: 0
# 40 {'atomic_number': 6, 'formal_charge': 0, 'atom_name': 'Cf', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 5, 'connors_atom_name': 'C1'}
# Formal charge: 0
# 41 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'Hp', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 5, 'connors_atom_name': 'H1'}
# Formal charge: 0
# 42 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'Hq', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 5, 'connors_atom_name': 'H2'}
# Formal charge: 0
# 43 {'atomic_number': 6, 'formal_charge': 0, 'atom_name': 'Cg', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 5, 'connors_atom_name': 'C2'}
# Formal charge: 0
# 44 {'atomic_number': 6, 'formal_charge': 0, 'atom_name': 'Ch', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 5, 'connors_atom_name': 'C3'}
# Formal charge: 0
# 45 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'Hr', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 5, 'connors_atom_name': 'H3'}
# Formal charge: 0
# 46 {'atomic_number': 6, 'formal_charge': 0, 'atom_name': 'Ci', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 5, 'connors_atom_name': 'C4'}
# Formal charge: 0
# 47 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'Hs', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 5, 'connors_atom_name': 'H4'}
# Formal charge: 0
# 48 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'Ht', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 5, 'connors_atom_name': 'H5'}
# Formal charge: 0
# 49 {'atomic_number': 6, 'formal_charge': 0, 'atom_name': 'Cj', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 5, 'connors_atom_name': 'C5'}
# Formal charge: 0
# 50 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'Hu', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 5, 'connors_atom_name': 'H6'}
# Formal charge: 0
# 51 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'Hv', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 5, 'connors_atom_name': 'H7'}
# Formal charge: 0
# 52 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'Hw', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 5, 'connors_atom_name': 'H8'}
# Formal charge: 0
# 53 {'atomic_number': 6, 'formal_charge': 0, 'atom_name': 'Ck', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 6, 'connors_atom_name': 'C1'}
# Formal charge: 0
# 54 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'Hx', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 6, 'connors_atom_name': 'H1'}
# Formal charge: 0
# 55 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'Hz', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 6, 'connors_atom_name': 'H2'}
# Formal charge: 0
# 56 {'atomic_number': 6, 'formal_charge': 0, 'atom_name': 'Cl', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 6, 'connors_atom_name': 'C2'}
# Formal charge: 0
# 57 {'atomic_number': 6, 'formal_charge': 0, 'atom_name': 'Cm', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 6, 'connors_atom_name': 'C3'}
# Formal charge: 0
# 58 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'Hy', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 6, 'connors_atom_name': 'H3'}
# Formal charge: 0
# 59 {'atomic_number': 6, 'formal_charge': 0, 'atom_name': 'Cn', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 6, 'connors_atom_name': 'C4'}
# Formal charge: 0
# 60 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'HA', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 6, 'connors_atom_name': 'H4'}
# Formal charge: 0
# 61 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'HB', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 6, 'connors_atom_name': 'H5'}
# Formal charge: 0
# 62 {'atomic_number': 6, 'formal_charge': 0, 'atom_name': 'Co', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 6, 'connors_atom_name': 'C5'}
# Formal charge: 0
# 63 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'HC', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 6, 'connors_atom_name': 'H6'}
# Formal charge: 0
# 64 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'HD', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 6, 'connors_atom_name': 'H7'}
# Formal charge: 0
# 65 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'HE', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 6, 'connors_atom_name': 'H8'}
# Formal charge: 0
# 66 {'atomic_number': 6, 'formal_charge': 0, 'atom_name': 'Cp', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 7, 'connors_atom_name': 'C1'}
# Formal charge: 0
# 67 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'HF', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 7, 'connors_atom_name': 'H1'}
# Formal charge: 0
# 68 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'HG', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 7, 'connors_atom_name': 'H2'}
# Formal charge: 0
# 69 {'atomic_number': 6, 'formal_charge': 0, 'atom_name': 'Cq', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 7, 'connors_atom_name': 'C2'}
# Formal charge: 0
# 70 {'atomic_number': 6, 'formal_charge': 0, 'atom_name': 'Cr', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 7, 'connors_atom_name': 'C3'}
# Formal charge: 0
# 71 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'HH', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 7, 'connors_atom_name': 'H3'}
# Formal charge: 0
# 72 {'atomic_number': 6, 'formal_charge': 0, 'atom_name': 'Cs', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 7, 'connors_atom_name': 'C4'}
# Formal charge: 0
# 73 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'HI', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 7, 'connors_atom_name': 'H4'}
# Formal charge: 0
# 74 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'HJ', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 7, 'connors_atom_name': 'H5'}
# Formal charge: 0
# 75 {'atomic_number': 6, 'formal_charge': 0, 'atom_name': 'Ct', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 7, 'connors_atom_name': 'C5'}
# Formal charge: 0
# 76 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'HK', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 7, 'connors_atom_name': 'H6'}
# Formal charge: 0
# 77 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'HL', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 7, 'connors_atom_name': 'H7'}
# Formal charge: 0
# 78 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'HM', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 7, 'connors_atom_name': 'H8'}
# Formal charge: 0
# 79 {'atomic_number': 6, 'formal_charge': 0, 'atom_name': 'Cu', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 8, 'connors_atom_name': 'C1'}
# Formal charge: 0
# 80 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'HN', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 8, 'connors_atom_name': 'H1'}
# Formal charge: 0
# 81 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'HO', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 8, 'connors_atom_name': 'H2'}
# Formal charge: 0
# 82 {'atomic_number': 6, 'formal_charge': 0, 'atom_name': 'Cv', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 8, 'connors_atom_name': 'C2'}
# Formal charge: 0
# 83 {'atomic_number': 6, 'formal_charge': 0, 'atom_name': 'Cw', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 8, 'connors_atom_name': 'C3'}
# Formal charge: 0
# 84 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'HP', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 8, 'connors_atom_name': 'H3'}
# Formal charge: 0
# 85 {'atomic_number': 6, 'formal_charge': 0, 'atom_name': 'Cx', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 8, 'connors_atom_name': 'C4'}
# Formal charge: 0
# 86 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'HQ', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 8, 'connors_atom_name': 'H4'}
# Formal charge: 0
# 87 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'HR', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 8, 'connors_atom_name': 'H5'}
# Formal charge: 0
# 88 {'atomic_number': 6, 'formal_charge': 0, 'atom_name': 'Cz', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 8, 'connors_atom_name': 'C5'}
# Formal charge: 0
# 89 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'HS', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 8, 'connors_atom_name': 'H6'}
# Formal charge: 0
# 90 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'HT', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 8, 'connors_atom_name': 'H7'}
# Formal charge: 0
# 91 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'HU', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])-[C:4](=[C:5](-[H:6])-[C:7](-[H:8])-[H:9])-[C:10](-[H:11])(-[H:12])-[H:13]', 'connors_residue_number': 8, 'connors_atom_name': 'H8'}
# Formal charge: 0
# 92 {'atomic_number': 6, 'formal_charge': 0, 'atom_name': 'Cy', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])(-[H:4])-[C:5](=[C:6](-[H:7])-[C:8](-[H:9])-[H:10])-[C:11](-[H:12])(-[H:13])-[H:14]', 'connors_residue_number': 1, 'connors_atom_name': 'C1'}
# Formal charge: 0
# 93 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'HV', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])(-[H:4])-[C:5](=[C:6](-[H:7])-[C:8](-[H:9])-[H:10])-[C:11](-[H:12])(-[H:13])-[H:14]', 'connors_residue_number': 1, 'connors_atom_name': 'H1'}
# Formal charge: 0
# 94 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'HW', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])(-[H:4])-[C:5](=[C:6](-[H:7])-[C:8](-[H:9])-[H:10])-[C:11](-[H:12])(-[H:13])-[H:14]', 'connors_residue_number': 1, 'connors_atom_name': 'H2'}
# Formal charge: 0
# 95 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'HX', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])(-[H:4])-[C:5](=[C:6](-[H:7])-[C:8](-[H:9])-[H:10])-[C:11](-[H:12])(-[H:13])-[H:14]', 'connors_residue_number': 1, 'connors_atom_name': 'H3'}
# Formal charge: 0
# 96 {'atomic_number': 6, 'formal_charge': 0, 'atom_name': 'CA', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])(-[H:4])-[C:5](=[C:6](-[H:7])-[C:8](-[H:9])-[H:10])-[C:11](-[H:12])(-[H:13])-[H:14]', 'connors_residue_number': 1, 'connors_atom_name': 'C2'}
# Formal charge: 0
# 97 {'atomic_number': 6, 'formal_charge': 0, 'atom_name': 'CB', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])(-[H:4])-[C:5](=[C:6](-[H:7])-[C:8](-[H:9])-[H:10])-[C:11](-[H:12])(-[H:13])-[H:14]', 'connors_residue_number': 1, 'connors_atom_name': 'C3'}
# Formal charge: 0
# 98 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'HY', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])(-[H:4])-[C:5](=[C:6](-[H:7])-[C:8](-[H:9])-[H:10])-[C:11](-[H:12])(-[H:13])-[H:14]', 'connors_residue_number': 1, 'connors_atom_name': 'H4'}
# Formal charge: 0
# 99 {'atomic_number': 6, 'formal_charge': 0, 'atom_name': 'CC', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])(-[H:4])-[C:5](=[C:6](-[H:7])-[C:8](-[H:9])-[H:10])-[C:11](-[H:12])(-[H:13])-[H:14]', 'connors_residue_number': 1, 'connors_atom_name': 'C4'}
# Formal charge: 0
# 100 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'HZ', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])(-[H:4])-[C:5](=[C:6](-[H:7])-[C:8](-[H:9])-[H:10])-[C:11](-[H:12])(-[H:13])-[H:14]', 'connors_residue_number': 1, 'connors_atom_name': 'H5'}
# Formal charge: 0
# 101 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'H!', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])(-[H:4])-[C:5](=[C:6](-[H:7])-[C:8](-[H:9])-[H:10])-[C:11](-[H:12])(-[H:13])-[H:14]', 'connors_residue_number': 1, 'connors_atom_name': 'H6'}
# Formal charge: 0
# 102 {'atomic_number': 6, 'formal_charge': 0, 'atom_name': 'CD', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])(-[H:4])-[C:5](=[C:6](-[H:7])-[C:8](-[H:9])-[H:10])-[C:11](-[H:12])(-[H:13])-[H:14]', 'connors_residue_number': 1, 'connors_atom_name': 'C5'}
# Formal charge: 0
# 103 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'H@', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])(-[H:4])-[C:5](=[C:6](-[H:7])-[C:8](-[H:9])-[H:10])-[C:11](-[H:12])(-[H:13])-[H:14]', 'connors_residue_number': 1, 'connors_atom_name': 'H7'}
# Formal charge: 0
# 104 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'H#', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])(-[H:4])-[C:5](=[C:6](-[H:7])-[C:8](-[H:9])-[H:10])-[C:11](-[H:12])(-[H:13])-[H:14]', 'connors_residue_number': 1, 'connors_atom_name': 'H8'}
# Formal charge: 0
# 105 {'atomic_number': 1, 'formal_charge': 0, 'atom_name': 'H$', 'residue_name': 'UNL', 'residue_number': 0, 'already_matched': True, 'connors_residue_name': 'NATURALRUBBER: [C:1](-[H:2])(-[H:3])(-[H:4])-[C:5](=[C:6](-[H:7])-[C:8](-[H:9])-[H:10])-[C:11](-[H:12])(-[H:13])-[H:14]', 'connors_residue_number': 1, 'connors_atom_name': 'H9'}
# Formal charge: 0
# (0, 1) {'bond_order': 1}
# (0, 2) {'bond_order': 1}
# (0, 3) {'bond_order': 1}
# (0, 20) {'bond_order': 1}
# (3, 4) {'bond_order': 2}
# (3, 9) {'bond_order': 1}
# (4, 5) {'bond_order': 1}
# (4, 6) {'bond_order': 1}
# (6, 7) {'bond_order': 1}
# (6, 8) {'bond_order': 1}
# (6, 13) {'bond_order': 1}
# (9, 10) {'bond_order': 1}
# (9, 11) {'bond_order': 1}
# (9, 12) {'bond_order': 1}
# (14, 15) {'bond_order': 1}
# (14, 16) {'bond_order': 1}
# (14, 17) {'bond_order': 1}
# (14, 33) {'bond_order': 1}
# (17, 18) {'bond_order': 2}
# (17, 23) {'bond_order': 1}
# (18, 19) {'bond_order': 1}
# (18, 20) {'bond_order': 1}
# (20, 21) {'bond_order': 1}
# (20, 22) {'bond_order': 1}
# (23, 24) {'bond_order': 1}
# (23, 25) {'bond_order': 1}
# (23, 26) {'bond_order': 1}
# (27, 28) {'bond_order': 1}
# (27, 29) {'bond_order': 1}
# (27, 30) {'bond_order': 1}
# (27, 46) {'bond_order': 1}
# (30, 31) {'bond_order': 2}
# (30, 36) {'bond_order': 1}
# (31, 32) {'bond_order': 1}
# (31, 33) {'bond_order': 1}
# (33, 34) {'bond_order': 1}
# (33, 35) {'bond_order': 1}
# (36, 37) {'bond_order': 1}
# (36, 38) {'bond_order': 1}
# (36, 39) {'bond_order': 1}
# (40, 41) {'bond_order': 1}
# (40, 42) {'bond_order': 1}
# (40, 43) {'bond_order': 1}
# (40, 59) {'bond_order': 1}
# (43, 44) {'bond_order': 2}
# (43, 49) {'bond_order': 1}
# (44, 45) {'bond_order': 1}
# (44, 46) {'bond_order': 1}
# (46, 47) {'bond_order': 1}
# (46, 48) {'bond_order': 1}
# (49, 50) {'bond_order': 1}
# (49, 51) {'bond_order': 1}
# (49, 52) {'bond_order': 1}
# (53, 54) {'bond_order': 1}
# (53, 55) {'bond_order': 1}
# (53, 56) {'bond_order': 1}
# (53, 72) {'bond_order': 1}
# (56, 57) {'bond_order': 2}
# (56, 62) {'bond_order': 1}
# (57, 58) {'bond_order': 1}
# (57, 59) {'bond_order': 1}
# (59, 60) {'bond_order': 1}
# (59, 61) {'bond_order': 1}
# (62, 63) {'bond_order': 1}
# (62, 64) {'bond_order': 1}
# (62, 65) {'bond_order': 1}
# (66, 67) {'bond_order': 1}
# (66, 68) {'bond_order': 1}
# (66, 69) {'bond_order': 1}
# (66, 85) {'bond_order': 1}
# (69, 70) {'bond_order': 2}
# (69, 75) {'bond_order': 1}
# (70, 71) {'bond_order': 1}
# (70, 72) {'bond_order': 1}
# (72, 73) {'bond_order': 1}
# (72, 74) {'bond_order': 1}
# (75, 76) {'bond_order': 1}
# (75, 77) {'bond_order': 1}
# (75, 78) {'bond_order': 1}
# (79, 80) {'bond_order': 1}
# (79, 81) {'bond_order': 1}
# (79, 82) {'bond_order': 1}
# (79, 99) {'bond_order': 1}
# (82, 83) {'bond_order': 2}
# (82, 88) {'bond_order': 1}
# (83, 84) {'bond_order': 1}
# (83, 85) {'bond_order': 1}
# (85, 86) {'bond_order': 1}
# (85, 87) {'bond_order': 1}
# (88, 89) {'bond_order': 1}
# (88, 90) {'bond_order': 1}
# (88, 91) {'bond_order': 1}
# (92, 93) {'bond_order': 1}
# (92, 94) {'bond_order': 1}
# (92, 95) {'bond_order': 1}
# (92, 96) {'bond_order': 1}
# (96, 97) {'bond_order': 2}
# (96, 102) {'bond_order': 1}
# (97, 98) {'bond_order': 1}
# (97, 99) {'bond_order': 1}
# (99, 100) {'bond_order': 1}
# (99, 101) {'bond_order': 1}
# (102, 103) {'bond_order': 1}
# (102, 104) {'bond_order': 1}
# (102, 105) {'bond_order': 1}
# Number of atoms before sanitization: 106
# number of atoms assigned: 106
# number of bonds assigned: 105
# number of atoms not assigned: 0
# number of bonds not assigned: 0
# Warning: : Failed due to unspecified stereochemistry

# %%
print(entry)
# Out:
# <LibraryCharge smirks="[#6:1](-[H:2])(-[H:3])-[#6:4](=[#6:5](-[H:6])-[#6:7](-[H:8])-[H:9])-[#6:10](-[H:11])(-[H:12])-[H:13]" charge1="-0.04623 * elementary_charge" charge2="0.04329 * elementary_charge" charge3="0.04329 * elementary_charge" charge4="-0.11187 * elementary_charge" charge5="-0.17211001 * elementary_charge" charge6="0.11912 * elementary_charge" charge7="-0.048889999 * elementary_charge" charge8="0.041979998 * elementary_charge" charge9="0.041979998 * elementary_charge" charge10="-0.061949998 * elementary_charge" charge11="0.041250001 * elementary_charge" charge12="0.041250001 * elementary_charge" charge13="0.041250001 * elementary_charge"></LibraryCharge>
